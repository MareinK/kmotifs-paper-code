# %% [markdown]
# Code used to explore the average position of all rats of time (not used in thesis).

# %%
# %matplotlib inline
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
data_2013 = xr.open_dataset('../xarray/2013.nc')
data_2013 = xr.open_dataset('../xarray/2014.nc')

# %%
data_2013
# Out:
# <xarray.Dataset>
# Dimensions:      (rat: 10, session: 11, time: 45001)
# Coordinates:
#   * rat          (rat) object '108' '110' '112' '114' '116' '109' '111' ...
#   * session      (session) object 'injection1' 'injection2' 'injection3' ...
#   * time         (time) timedelta64[ns] 00:00:00 00:00:00.040000 ...
#     treatment    (rat) object 's' 's' 's' 's' 's' 'q' 'q' 'q' 'q' 'q'
#     trial        (rat, session) object '3' '15' '27' '39' '51' '63' '75' ...
# Data variables:
#     x            (rat, session, time) float64 -6.652 -6.611 -6.655 -6.743 ...
#     y            (rat, session, time) float64 44.87 44.99 45.19 45.45 45.6 ...
#     area         (rat, session, time) float64 70.59 70.76 71.27 70.59 69.99 ...
#     areachange   (rat, session, time) float64 6.956 6.526 7.557 6.87 2.49 ...
#     elongation   (rat, session, time) float64 0.7505 0.7632 0.773 0.781 ...
#     direction    (rat, session, time) float64 139.2 137.1 135.0 139.1 137.3 ...
# ...

# %%
d = data_2013.groupby('treatment').mean(dim=['rat','session'])
d
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 45001, treatment: 2)
# Coordinates:
#   * time         (time) timedelta64[ns] 00:00:00 00:00:00.040000 ...
#   * treatment    (treatment) object 'q' 's'
# Data variables:
#     x            (treatment, time) float64 3.477 3.446 2.756 2.779 2.473 ...
#     y            (treatment, time) float64 35.96 35.97 35.6 36.4 35.8 36.58 ...
#     area         (treatment, time) float64 70.24 69.6 69.57 72.09 70.49 73.8 ...
#     areachange   (treatment, time) float64 9.804 9.981 11.13 15.48 14.3 ...
#     elongation   (treatment, time) float64 0.676 0.667 0.6706 0.699 0.693 ...
#     direction    (treatment, time) float64 20.97 17.97 20.65 18.46 22.27 ...
#     time_offset  (treatment) float64 7.793 7.761

# %%
x = d.isel(treatment=0)
plt.plot(x.x,x.y)

# %%
x = d.isel(treatment=1)
plt.plot(x.x,x.y)

# %%
x = d.isel(treatment=2)
plt.plot(x.x,x.y)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-3571d6370fad> in <module>()
# ----> 1 x = d.isel(treatment=2)
#       2 plt.plot(x.x,x.y)
#
# /usr/lib/python3.6/site-packages/xarray/core/dataset.py in isel(self, drop, **indexers)
#    1117         for name, var in iteritems(self._variables):
#    1118             var_indexers = dict((k, v) for k, v in indexers if k in var.dims)
# -> 1119             new_var = var.isel(**var_indexers)
#    1120             if not (drop and name in var_indexers):
#    1121                 variables[name] = new_var
#
# /usr/lib/python3.6/site-packages/xarray/core/variable.py in isel(self, **indexers)
#     545             if dim in indexers:
#     546                 key[i] = indexers[dim]
# --> 547         return self[tuple(key)]
#     548
#     549     def squeeze(self, dim=None):
#
# ...

# %%
x = d.isel(treatment=3)
plt.plot(x.x,x.y)
